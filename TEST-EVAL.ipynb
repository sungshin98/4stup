# %%
import csv
import numpy as np
import os
import pandas as pd
import seaborn as sns

# %%
Sess01 = pd.read_csv('./KEMDy20/annotation/Sess01_eval.csv')
Sess01
# Out:
#     Numb        WAV                               Segment ID Total Evaluation  \
# 0             start        end                                        Emotion
# 1      1  3.5783901  11.637391  Sess01_script01_User002M_001          neutral
# 2      2  11.637391  23.334393  Sess01_script01_User002M_002          neutral
# 3      3  23.334393  31.558392  Sess01_script01_User002M_003          neutral
# 4      4  31.558392   42.97039  Sess01_script01_User002M_004          neutral
# ..   ...        ...        ...                           ...              ...
# 307  307  318.79968   331.0077  Sess01_script06_User001F_016          neutral
# 308  308  328.94327  333.90628  Sess01_script06_User002M_041          neutral
# 309  309  333.90628  336.59326  Sess01_script06_User002M_042          neutral
# 310  310  336.59326  337.92126  Sess01_script06_User002M_043          neutral
# 311  311   338.8657   347.5847  Sess01_script06_User001F_017          neutral
#
# ...

# %%
Sess01.columns
# Out:
# Index(['Numb', 'WAV', ' ', 'Segment ID', 'Total Evaluation', ' .1', ' .2',
#        'Eval01F', ' .3', ' .4', 'Eval02M', ' .5', ' .6', 'Eval03M', ' .7',
#        ' .8', 'Eval04F', ' .9', ' .10', 'Eval05M', ' .11', ' .12', 'Eval06F',
#        ' .13', ' .14', 'Eval07F', ' .15', ' .16', 'Eval08M', ' .17', ' .18',
#        'Eval09F', ' .19', ' .20', 'Eval10M', ' .21', ' .22'],
#       dtype='object')

# %%
file_list = os.listdir('./KEMDy20/annotation/')
file_list
# Out:
# ['Sess11_eval.csv',
#  'Sess10_eval.csv',
#  'Sess25_eval.csv',
#  'Sess24_eval.csv',
#  'Sess06_eval.csv',
#  'Sess07_eval.csv',
#  'Sess38_eval.csv',
#  'Sess39_eval.csv',
#  'Sess32_eval.csv',
#  'Sess33_eval.csv',
#  'Sess01_eval.csv',
#  'Sess35_eval.csv',
#  'Sess34_eval.csv',
#  'Sess16_eval.csv',
#  'Sess17_eval.csv',
#  'Sess28_eval.csv',
#  'Sess29_eval.csv',
#  'Sess22_eval.csv',
#  'Sess23_eval.csv',
#  'Sess31_eval.csv',
#  'Sess30_eval.csv',
#  'Sess05_eval.csv',
#  'Sess04_eval.csv',
#  'Sess18_eval.csv',
#  'Sess19_eval.csv',
#  'Sess26_eval.csv',
#  'Sess27_eval.csv',
#  'Sess12_eval.csv',
#  'Sess13_eval.csv',
#  'Sess21_eval.csv',
#  'Sess20_eval.csv',
#  'Sess15_eval.csv',
#  'Sess14_eval.csv',
#  'Sess08_eval.csv',
#  'Sess09_eval.csv',
#  'Sess40_eval.csv',
#  'Sess36_eval.csv',
#  'Sess37_eval.csv',
#  'Sess02_eval.csv',
#  'Sess03_eval.csv']

# %%
folder_list = os.listdir('./KEMDy20/annotation/')
script_list = ['script01', 'script02', 'script03', 'script04', 'script05', 'script06']

print(folder_list)

if '.DS_Store' in folder_list:
    folder_list.remove('.DS_Store')

if '.ipynb_checkpoints' in folder_list:
    folder_list.remove('.ipynb_checkpoints')
    
print(folder_list)

for folder in folder_list:
    folder_route = './KEMDy20/IBI/' + folder
    file_list = os.listdir(folder_route)
    
    for script in script_list:
        script_file_list = []
        for file in file_list:
            if script in file:
                script_file_list.append(file)

        print(script_file_list)
